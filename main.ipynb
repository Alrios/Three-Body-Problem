# %%
# %run main.py

# %%
import matplotlib.pyplot as plt
fig, (ax1, ax2) = plt.subplots(2, 1)

fig.set_size_inches(20, 20) 
ax1.plot(satelData_1["x"], satelData_1["y"], color ="red", label = "Satellite")
ax1.plot(earthData["x"], earthData["y"], label = "Earth")
ax1.legend(prop={'size': 20})
ax1.grid(True)
ax1.text(-1e7,-0.5e7, r"$v_0 =$"+str(z0[3])+" m/s")

ax2.grid(True)
ax2.plot(satelData_2["x"], satelData_2["y"], color ="red", label = "Satellite")
ax2.plot(earthData["x"], earthData["y"], label = "Earth")
ax2.legend(prop={'size': 20})
ax2.text(-2e9,0.2e9, r"$v_0 =$"+str(z0_1[3])+" m/s")

ax1.set_title("Satellite Motion with "+r" $v_0 < v_e$ "+r"($v_e = 11186$"+" m/s)")
ax2.set_title("Satellite Motion with "+r" $v_0 = v_e = 11186$"+" m/s")

ax1.set_xlabel("x")
ax2.set_xlabel("x")

ax1.set_ylabel("y")
ax2.set_ylabel("y")
plt.savefig("result.png", dpi=400, bbox_inches="tight")
