# %%
# %run main.py
# Out:
# D:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\scipy\integrate\odepack.py:236: ODEintWarning: Excess work done on this call (perhaps wrong Dfun type). Run with full_output = 1 to get quantitative information.
#   warnings.warn(warning_msg, ODEintWarning)

# %%
z0[3]
# Out:
# 3.344697295720496

# %%
import matplotlib.pyplot as plt

fig = plt.figure(frameon = False)
fig.set_size_inches(20, 20) 
plt.plot(satelData["x"], satelData["y"], color ="red", label = "Satellite")
plt.plot(earthData["x"], earthData["y"], label = "Earth")
#plt.plot(moonData["x"], moonData["y"], label = "Moon")
plt.legend(prop={'size': 20})
plt.grid(True)
plt.savefig("foto")
plt.show()
